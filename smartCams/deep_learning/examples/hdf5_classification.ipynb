# %% [markdown]
# # Caffeinated Logistic Regression of HDF5 Data
#
# While Caffe is made for deep networks it can likewise represent "shallow" models like logistic regression for classification. We'll do simple logistic regression on synthetic data that we'll generate and save to HDF5 to feed vectors to Caffe. Once that model is done, we'll add layers to improve accuracy. That's what Caffe is about: define a model, experiment, and then deploy.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Make sure that caffe is on the python path:
caffe_root = '/users/cusgadmin/'  # this file is expected to be in {caffe_root}/examples
import sys
sys.path.insert(0, caffe_root + 'python')

import caffe

import os
import h5py
import shutil
import tempfile

# You may need to 'pip install scikit-learn'
import sklearn
import sklearn.datasets
import sklearn.linear_model

# %% [markdown]
# Synthesize a dataset of 10,000 4-vectors for binary classification with 2 informative features and 2 noise features.

# %%
import pandas as pd

X, y = sklearn.datasets.make_classification(
    n_samples=10000, n_features=4, n_redundant=0, n_informative=2, 
    n_clusters_per_class=2, hypercube=False, random_state=0
)

# Split into train and test
X, Xt, y, yt = sklearn.cross_validation.train_test_split(X, y)

# Visualize sample of the data
ind = np.random.permutation(X.shape[0])[:1000]
df = pd.DataFrame(X[ind])
_ = pd.scatter_matrix(df, figsize=(9, 9), diagonal='kde', marker='o', s=40, alpha=.4, c=y[ind])

# %% [markdown]
# Learn and evaluate scikit-learn's logistic regression with stochastic gradient descent (SGD) training. Time and check the classifier's accuracy.

# %%
# Train and test the scikit-learn SGD logistic regression.
clf = sklearn.linear_model.SGDClassifier(
    loss='log', n_iter=1000, penalty='l2', alpha=1e-3, class_weight='auto')

# %timeit clf.fit(X, y)
yt_pred = clf.predict(Xt)
print('Accuracy: {:.3f}'.format(sklearn.metrics.accuracy_score(yt, yt_pred)))
# Out:
# 1 loops, best of 3: 450 ms per loop
# Accuracy: 0.774

# %% [markdown]
# Save the dataset to HDF5 for loading in Caffe.

# %%
# Write out the data to HDF5 files in a temp directory.
# This file is assumed to be caffe_root/examples/hdf5_classification.ipynb
dirname = os.path.abspath('./hdf5_classification/data')
if not os.path.exists(dirname):
    os.makedirs(dirname)

train_filename = os.path.join(dirname, 'train.h5')
test_filename = os.path.join(dirname, 'test.h5')

# HDF5DataLayer source should be a file containing a list of HDF5 filenames.
# To show this off, we'll list the same data file twice.
with h5py.File(train_filename, 'w') as f:
    f['data'] = X
    f['label'] = y.astype(np.float32)
with open(os.path.join(dirname, 'train.txt'), 'w') as f:
    f.write(train_filename + '\n')
    f.write(train_filename + '\n')
    
# HDF5 is pretty efficient, but can be further compressed.
comp_kwargs = {'compression': 'gzip', 'compression_opts': 1}
with h5py.File(test_filename, 'w') as f:
    f.create_dataset('data', data=Xt, **comp_kwargs)
    f.create_dataset('label', data=yt.astype(np.float32), **comp_kwargs)
with open(os.path.join(dirname, 'test.txt'), 'w') as f:
    f.write(test_filename + '\n')

# %% [markdown]
# Learn and evaluate logistic regression in Caffe.

# %%
def learn_and_test(solver_file):
    caffe.set_mode_cpu()
    solver = caffe.get_solver(solver_file)
    solver.solve()

    accuracy = 0
    test_iters = int(len(Xt) / solver.test_nets[0].blobs['data'].num)
    for i in range(test_iters):
        solver.test_nets[0].forward()
        accuracy += solver.test_nets[0].blobs['accuracy'].data
    accuracy /= test_iters
    return accuracy

# %timeit learn_and_test('hdf5_classification/solver.prototxt')
acc = learn_and_test('hdf5_classification/solver.prototxt')
print("Accuracy: {:.3f}".format(acc))
# Out:
# 10 loops, best of 3: 148 ms per loop
# Accuracy: 0.776

# %% [markdown]
# Do the same through the command line interface for detailed output on the model and solving.

# %%
# !/users/cusgadmin/caffe/build/tools/caffe train -solver hdf5_classification/solver.prototxt
# Out:
# I0427 18:17:33.111665 2050462464 caffe.cpp:117] Use CPU.
# I0427 18:17:33.113324 2050462464 caffe.cpp:121] Starting Optimization
# I0427 18:17:33.113528 2050462464 solver.cpp:32] Initializing solver from parameters:
# test_iter: 250
# test_interval: 1000
# base_lr: 0.01
# display: 1000
# max_iter: 10000
# lr_policy: "step"
# gamma: 0.1
# momentum: 0.9
# weight_decay: 0.0005
# stepsize: 5000
# snapshot: 10000
# snapshot_prefix: "hdf5_classification/data/train"
# solver_mode: CPU
# net: "hdf5_classification/train_val.prototxt"
# I0427 18:17:33.113628 2050462464 solver.cpp:70] Creating training net from net file: hdf5_classification/train_val.prototxt
# I0427 18:17:33.113796 2050462464 net.cpp:257] The NetState phase (0) differed from the phase (1) specified by a rule in layer data
# I0427 18:17:33.113814 2050462464 net.cpp:257] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# I0427 18:17:33.113824 2050462464 net.cpp:42] Initializing net from parameters:
# name: "LogisticRegressionNet"
# state {
#   phase: TRAIN
# }
# layer {
#   name: "data"
#   type: "HDF5Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TRAIN
#   }
#   hdf5_data_param {
#     source: "hdf5_classification/data/train.txt"
#     batch_size: 10
#   }
# }
# layer {
#   name: "fc1"
#   type: "InnerProduct"
#   bottom: "data"
#   top: "fc1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc1"
#   bottom: "label"
#   top: "loss"
# }
# I0427 18:17:33.114544 2050462464 layer_factory.hpp:74] Creating layer data
# I0427 18:17:33.114565 2050462464 net.cpp:84] Creating Layer data
# I0427 18:17:33.114575 2050462464 net.cpp:338] data -> data
# I0427 18:17:33.114598 2050462464 net.cpp:338] data -> label
# I0427 18:17:33.114605 2050462464 net.cpp:113] Setting up data
# I0427 18:17:33.114611 2050462464 hdf5_data_layer.cpp:80] Loading list of HDF5 filenames from: hdf5_classification/data/train.txt
# I0427 18:17:33.114758 2050462464 hdf5_data_layer.cpp:94] Number of HDF5 files: 2
# I0427 18:17:33.117120 2050462464 net.cpp:120] Top shape: 10 4 (40)
# I0427 18:17:33.117148 2050462464 net.cpp:120] Top shape: 10 (10)
# I0427 18:17:33.117161 2050462464 layer_factory.hpp:74] Creating layer fc1
# I0427 18:17:33.117182 2050462464 net.cpp:84] Creating Layer fc1
# I0427 18:17:33.117193 2050462464 net.cpp:380] fc1 <- data
# I0427 18:17:33.117202 2050462464 net.cpp:338] fc1 -> fc1
# I0427 18:17:33.117211 2050462464 net.cpp:113] Setting up fc1
# I0427 18:17:33.124141 2050462464 net.cpp:120] Top shape: 10 2 (20)
# I0427 18:17:33.124163 2050462464 layer_factory.hpp:74] Creating layer loss
# I0427 18:17:33.124176 2050462464 net.cpp:84] Creating Layer loss
# I0427 18:17:33.124186 2050462464 net.cpp:380] loss <- fc1
# I0427 18:17:33.124191 2050462464 net.cpp:380] loss <- label
# I0427 18:17:33.124202 2050462464 net.cpp:338] loss -> loss
# I0427 18:17:33.124213 2050462464 net.cpp:113] Setting up loss
# I0427 18:17:33.124219 2050462464 layer_factory.hpp:74] Creating layer loss
# I0427 18:17:33.124233 2050462464 net.cpp:120] Top shape: (1)
# I0427 18:17:33.124239 2050462464 net.cpp:122]     with loss weight 1
# I0427 18:17:33.124253 2050462464 net.cpp:167] loss needs backward computation.
# I0427 18:17:33.124261 2050462464 net.cpp:167] fc1 needs backward computation.
# I0427 18:17:33.124267 2050462464 net.cpp:169] data does not need backward computation.
# I0427 18:17:33.124271 2050462464 net.cpp:205] This network produces output loss
# I0427 18:17:33.124276 2050462464 net.cpp:447] Collecting Learning Rate and Weight Decay.
# I0427 18:17:33.124281 2050462464 net.cpp:217] Network initialization done.
# I0427 18:17:33.124285 2050462464 net.cpp:218] Memory required for data: 284
# I0427 18:17:33.124404 2050462464 solver.cpp:154] Creating test net (#0) specified by net file: hdf5_classification/train_val.prototxt
# I0427 18:17:33.124423 2050462464 net.cpp:257] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0427 18:17:33.124434 2050462464 net.cpp:42] Initializing net from parameters:
# name: "LogisticRegressionNet"
# state {
#   phase: TEST
# }
# layer {
#   name: "data"
#   type: "HDF5Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_data_param {
#     source: "hdf5_classification/data/test.txt"
#     batch_size: 10
#   }
# }
# layer {
#   name: "fc1"
#   type: "InnerProduct"
#   bottom: "data"
#   top: "fc1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc1"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc1"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0427 18:17:33.124550 2050462464 layer_factory.hpp:74] Creating layer data
# I0427 18:17:33.124652 2050462464 net.cpp:84] Creating Layer data
# I0427 18:17:33.124666 2050462464 net.cpp:338] data -> data
# I0427 18:17:33.124676 2050462464 net.cpp:338] data -> label
# I0427 18:17:33.124685 2050462464 net.cpp:113] Setting up data
# I0427 18:17:33.124688 2050462464 hdf5_data_layer.cpp:80] Loading list of HDF5 filenames from: hdf5_classification/data/test.txt
# I0427 18:17:33.124723 2050462464 hdf5_data_layer.cpp:94] Number of HDF5 files: 1
# I0427 18:17:33.125833 2050462464 net.cpp:120] Top shape: 10 4 (40)
# I0427 18:17:33.125849 2050462464 net.cpp:120] Top shape: 10 (10)
# I0427 18:17:33.125854 2050462464 layer_factory.hpp:74] Creating layer label_data_1_split
# I0427 18:17:33.125862 2050462464 net.cpp:84] Creating Layer label_data_1_split
# I0427 18:17:33.125867 2050462464 net.cpp:380] label_data_1_split <- label
# I0427 18:17:33.125874 2050462464 net.cpp:338] label_data_1_split -> label_data_1_split_0
# I0427 18:17:33.125882 2050462464 net.cpp:338] label_data_1_split -> label_data_1_split_1
# I0427 18:17:33.125888 2050462464 net.cpp:113] Setting up label_data_1_split
# I0427 18:17:33.125895 2050462464 net.cpp:120] Top shape: 10 (10)
# I0427 18:17:33.125898 2050462464 net.cpp:120] Top shape: 10 (10)
# I0427 18:17:33.125903 2050462464 layer_factory.hpp:74] Creating layer fc1
# I0427 18:17:33.125910 2050462464 net.cpp:84] Creating Layer fc1
# I0427 18:17:33.125915 2050462464 net.cpp:380] fc1 <- data
# I0427 18:17:33.125921 2050462464 net.cpp:338] fc1 -> fc1
# I0427 18:17:33.125927 2050462464 net.cpp:113] Setting up fc1
# I0427 18:17:33.125939 2050462464 net.cpp:120] Top shape: 10 2 (20)
# I0427 18:17:33.125947 2050462464 layer_factory.hpp:74] Creating layer fc1_fc1_0_split
# I0427 18:17:33.125953 2050462464 net.cpp:84] Creating Layer fc1_fc1_0_split
# I0427 18:17:33.126004 2050462464 net.cpp:380] fc1_fc1_0_split <- fc1
# I0427 18:17:33.126021 2050462464 net.cpp:338] fc1_fc1_0_split -> fc1_fc1_0_split_0
# I0427 18:17:33.126030 2050462464 net.cpp:338] fc1_fc1_0_split -> fc1_fc1_0_split_1
# I0427 18:17:33.126037 2050462464 net.cpp:113] Setting up fc1_fc1_0_split
# I0427 18:17:33.126044 2050462464 net.cpp:120] Top shape: 10 2 (20)
# I0427 18:17:33.126049 2050462464 net.cpp:120] Top shape: 10 2 (20)
# I0427 18:17:33.126054 2050462464 layer_factory.hpp:74] Creating layer loss
# I0427 18:17:33.126060 2050462464 net.cpp:84] Creating Layer loss
# I0427 18:17:33.126065 2050462464 net.cpp:380] loss <- fc1_fc1_0_split_0
# I0427 18:17:33.126070 2050462464 net.cpp:380] loss <- label_data_1_split_0
# I0427 18:17:33.126076 2050462464 net.cpp:338] loss -> loss
# I0427 18:17:33.126082 2050462464 net.cpp:113] Setting up loss
# I0427 18:17:33.126087 2050462464 layer_factory.hpp:74] Creating layer loss
# I0427 18:17:33.126098 2050462464 net.cpp:120] Top shape: (1)
# I0427 18:17:33.126145 2050462464 net.cpp:122]     with loss weight 1
# I0427 18:17:33.126158 2050462464 layer_factory.hpp:74] Creating layer accuracy
# I0427 18:17:33.126171 2050462464 net.cpp:84] Creating Layer accuracy
# I0427 18:17:33.126176 2050462464 net.cpp:380] accuracy <- fc1_fc1_0_split_1
# I0427 18:17:33.126183 2050462464 net.cpp:380] accuracy <- label_data_1_split_1
# I0427 18:17:33.126188 2050462464 net.cpp:338] accuracy -> accuracy
# I0427 18:17:33.126215 2050462464 net.cpp:113] Setting up accuracy
# I0427 18:17:33.126224 2050462464 net.cpp:120] Top shape: (1)
# I0427 18:17:33.126230 2050462464 net.cpp:169] accuracy does not need backward computation.
# I0427 18:17:33.126235 2050462464 net.cpp:167] loss needs backward computation.
# I0427 18:17:33.126238 2050462464 net.cpp:167] fc1_fc1_0_split needs backward computation.
# I0427 18:17:33.126242 2050462464 net.cpp:167] fc1 needs backward computation.
# I0427 18:17:33.126246 2050462464 net.cpp:169] label_data_1_split does not need backward computation.
# I0427 18:17:33.126269 2050462464 net.cpp:169] data does not need backward computation.
# I0427 18:17:33.126274 2050462464 net.cpp:205] This network produces output accuracy
# I0427 18:17:33.126279 2050462464 net.cpp:205] This network produces output loss
# I0427 18:17:33.126286 2050462464 net.cpp:447] Collecting Learning Rate and Weight Decay.
# I0427 18:17:33.126291 2050462464 net.cpp:217] Network initialization done.
# I0427 18:17:33.126294 2050462464 net.cpp:218] Memory required for data: 528
# I0427 18:17:33.126323 2050462464 solver.cpp:42] Solver scaffolding done.
# I0427 18:17:33.126339 2050462464 solver.cpp:222] Solving LogisticRegressionNet
# I0427 18:17:33.126343 2050462464 solver.cpp:223] Learning Rate Policy: step
# I0427 18:17:33.126349 2050462464 solver.cpp:266] Iteration 0, Testing net (#0)
# I0427 18:17:33.128139 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.3884
# I0427 18:17:33.128154 2050462464 solver.cpp:315]     Test net output #1: loss = 0.697538 (* 1 = 0.697538 loss)
# I0427 18:17:33.128171 2050462464 solver.cpp:189] Iteration 0, loss = 0.697732
# I0427 18:17:33.128180 2050462464 solver.cpp:204]     Train net output #0: loss = 0.697732 (* 1 = 0.697732 loss)
# I0427 18:17:33.128188 2050462464 solver.cpp:464] Iteration 0, lr = 0.01
# I0427 18:17:33.133246 2050462464 solver.cpp:266] Iteration 1000, Testing net (#0)
# I0427 18:17:33.135371 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.7564
# I0427 18:17:33.135478 2050462464 solver.cpp:315]     Test net output #1: loss = 0.576881 (* 1 = 0.576881 loss)
# I0427 18:17:33.135514 2050462464 solver.cpp:189] Iteration 1000, loss = 0.797627
# I0427 18:17:33.135525 2050462464 solver.cpp:204]     Train net output #0: loss = 0.797627 (* 1 = 0.797627 loss)
# I0427 18:17:33.135536 2050462464 solver.cpp:464] Iteration 1000, lr = 0.01
# I0427 18:17:33.142974 2050462464 solver.cpp:266] Iteration 2000, Testing net (#0)
# I0427 18:17:33.145509 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.6864
# I0427 18:17:33.145534 2050462464 solver.cpp:315]     Test net output #1: loss = 0.589502 (* 1 = 0.589502 loss)
# I0427 18:17:33.145552 2050462464 solver.cpp:189] Iteration 2000, loss = 0.576644
# I0427 18:17:33.145560 2050462464 solver.cpp:204]     Train net output #0: loss = 0.576644 (* 1 = 0.576644 loss)
# I0427 18:17:33.145567 2050462464 solver.cpp:464] Iteration 2000, lr = 0.01
# I0427 18:17:33.152334 2050462464 solver.cpp:266] Iteration 3000, Testing net (#0)
# I0427 18:17:33.154345 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.676
# I0427 18:17:33.154435 2050462464 solver.cpp:315]     Test net output #1: loss = 0.587358 (* 1 = 0.587358 loss)
# I0427 18:17:33.155100 2050462464 solver.cpp:189] Iteration 3000, loss = 0.614075
# I0427 18:17:33.155119 2050462464 solver.cpp:204]     Train net output #0: loss = 0.614075 (* 1 = 0.614075 loss)
# I0427 18:17:33.155128 2050462464 solver.cpp:464] Iteration 3000, lr = 0.01
# I0427 18:17:33.160223 2050462464 solver.cpp:266] Iteration 4000, Testing net (#0)
# I0427 18:17:33.162124 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.7564
# I0427 18:17:33.162147 2050462464 solver.cpp:315]     Test net output #1: loss = 0.576881 (* 1 = 0.576881 loss)
# I0427 18:17:33.162163 2050462464 solver.cpp:189] Iteration 4000, loss = 0.797626
# I0427 18:17:33.162184 2050462464 solver.cpp:204]     Train net output #0: loss = 0.797626 (* 1 = 0.797626 loss)
# I0427 18:17:33.162189 2050462464 solver.cpp:464] Iteration 4000, lr = 0.01
# I0427 18:17:33.167455 2050462464 solver.cpp:266] Iteration 5000, Testing net (#0)
# I0427 18:17:33.169268 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.6864
# I0427 18:17:33.169284 2050462464 solver.cpp:315]     Test net output #1: loss = 0.589502 (* 1 = 0.589502 loss)
# I0427 18:17:33.169296 2050462464 solver.cpp:189] Iteration 5000, loss = 0.576644
# I0427 18:17:33.169303 2050462464 solver.cpp:204]     Train net output #0: loss = 0.576644 (* 1 = 0.576644 loss)
# I0427 18:17:33.169311 2050462464 solver.cpp:464] Iteration 5000, lr = 0.001
# I0427 18:17:33.174190 2050462464 solver.cpp:266] Iteration 6000, Testing net (#0)
# I0427 18:17:33.175940 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.7748
# I0427 18:17:33.175951 2050462464 solver.cpp:315]     Test net output #1: loss = 0.575274 (* 1 = 0.575274 loss)
# I0427 18:17:33.176318 2050462464 solver.cpp:189] Iteration 6000, loss = 0.624061
# I0427 18:17:33.176333 2050462464 solver.cpp:204]     Train net output #0: loss = 0.624061 (* 1 = 0.624061 loss)
# I0427 18:17:33.176340 2050462464 solver.cpp:464] Iteration 6000, lr = 0.001
# I0427 18:17:33.181216 2050462464 solver.cpp:266] Iteration 7000, Testing net (#0)
# I0427 18:17:33.183043 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.776
# I0427 18:17:33.183068 2050462464 solver.cpp:315]     Test net output #1: loss = 0.574715 (* 1 = 0.574715 loss)
# I0427 18:17:33.183081 2050462464 solver.cpp:189] Iteration 7000, loss = 0.795807
# I0427 18:17:33.183089 2050462464 solver.cpp:204]     Train net output #0: loss = 0.795807 (* 1 = 0.795807 loss)
# I0427 18:17:33.183095 2050462464 solver.cpp:464] Iteration 7000, lr = 0.001
# I0427 18:17:33.188109 2050462464 solver.cpp:266] Iteration 8000, Testing net (#0)
# I0427 18:17:33.189843 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.7728
# I0427 18:17:33.189856 2050462464 solver.cpp:315]     Test net output #1: loss = 0.575407 (* 1 = 0.575407 loss)
# I0427 18:17:33.189867 2050462464 solver.cpp:189] Iteration 8000, loss = 0.627704
# I0427 18:17:33.189874 2050462464 solver.cpp:204]     Train net output #0: loss = 0.627704 (* 1 = 0.627704 loss)
# I0427 18:17:33.189880 2050462464 solver.cpp:464] Iteration 8000, lr = 0.001
# I0427 18:17:33.194712 2050462464 solver.cpp:266] Iteration 9000, Testing net (#0)
# I0427 18:17:33.196424 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.776
# I0427 18:17:33.196435 2050462464 solver.cpp:315]     Test net output #1: loss = 0.575066 (* 1 = 0.575066 loss)
# I0427 18:17:33.196871 2050462464 solver.cpp:189] Iteration 9000, loss = 0.622889
# I0427 18:17:33.196887 2050462464 solver.cpp:204]     Train net output #0: loss = 0.622889 (* 1 = 0.622889 loss)
# I0427 18:17:33.196893 2050462464 solver.cpp:464] Iteration 9000, lr = 0.001
# I0427 18:17:33.203122 2050462464 solver.cpp:334] Snapshotting to hdf5_classification/data/train_iter_10000.caffemodel
# I0427 18:17:33.203294 2050462464 solver.cpp:342] Snapshotting solver state to hdf5_classification/data/train_iter_10000.solverstate
# I0427 18:17:33.203402 2050462464 solver.cpp:248] Iteration 10000, loss = 0.79604
# I0427 18:17:33.203416 2050462464 solver.cpp:266] Iteration 10000, Testing net (#0)
# I0427 18:17:33.205134 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.7756
# I0427 18:17:33.205147 2050462464 solver.cpp:315]     Test net output #1: loss = 0.574676 (* 1 = 0.574676 loss)
# I0427 18:17:33.205152 2050462464 solver.cpp:253] Optimization Done.
# I0427 18:17:33.205157 2050462464 caffe.cpp:134] Optimization Done.

# %% [markdown]
# If you look at output or the `train_val.prototxt`, you'll see that the model is simple logistic regression.
# We can make it a little more advanced by introducing a non-linearity between weights that take the input and weights that give the output -- now we have a two-layer network.
# That network is given in `train_val2.prototxt`, and that's the only change made in `solver2.prototxt` which we will now use.
#
# The final accuracy of the new network be higher than logistic regression!

# %%
def learn_and_test(solver_file):
    caffe.set_mode_cpu()
    solver = caffe.get_solver(solver_file)
    solver.solve()

    accuracy = 0
    test_iters = int(len(Xt) / solver.test_nets[0].blobs['data'].num)
    for i in range(test_iters):
        solver.test_nets[0].forward()
        accuracy += solver.test_nets[0].blobs['accuracy'].data
    accuracy /= test_iters
    return accuracy

# %timeit learn_and_test('hdf5_classification/solver2.prototxt')
acc = learn_and_test('hdf5_classification/solver2.prototxt')
print("Accuracy: {:.3f}".format(acc))
# Out:
# 1 loops, best of 3: 205 ms per loop
# Accuracy: 0.839

# %% [markdown]
# Do the same through the command line interface for detailed output on the model and solving.

# %%
# !/users/cusgadmin/caffe/build/tools/caffe train -solver hdf5_classification/solver2.prototxt
# Out:
# I0427 18:17:57.359344 2050462464 caffe.cpp:117] Use CPU.
# I0427 18:17:57.360226 2050462464 caffe.cpp:121] Starting Optimization
# I0427 18:17:57.360242 2050462464 solver.cpp:32] Initializing solver from parameters:
# test_iter: 250
# test_interval: 1000
# base_lr: 0.01
# display: 1000
# max_iter: 10000
# lr_policy: "step"
# gamma: 0.1
# momentum: 0.9
# weight_decay: 0.0005
# stepsize: 5000
# snapshot: 10000
# snapshot_prefix: "hdf5_classification/data/train"
# solver_mode: CPU
# net: "hdf5_classification/train_val2.prototxt"
# I0427 18:17:57.360311 2050462464 solver.cpp:70] Creating training net from net file: hdf5_classification/train_val2.prototxt
# I0427 18:17:57.360458 2050462464 net.cpp:257] The NetState phase (0) differed from the phase (1) specified by a rule in layer data
# I0427 18:17:57.360473 2050462464 net.cpp:257] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# I0427 18:17:57.360481 2050462464 net.cpp:42] Initializing net from parameters:
# name: "LogisticRegressionNet"
# state {
#   phase: TRAIN
# }
# layer {
#   name: "data"
#   type: "HDF5Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TRAIN
#   }
#   hdf5_data_param {
#     source: "hdf5_classification/data/train.txt"
#     batch_size: 10
#   }
# }
# layer {
#   name: "fc1"
#   type: "InnerProduct"
#   bottom: "data"
#   top: "fc1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 40
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "fc1"
#   top: "fc1"
# }
# layer {
#   name: "fc2"
#   type: "InnerProduct"
#   bottom: "fc1"
#   top: "fc2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc2"
#   bottom: "label"
#   top: "loss"
# }
# I0427 18:17:57.360748 2050462464 layer_factory.hpp:74] Creating layer data
# I0427 18:17:57.360764 2050462464 net.cpp:84] Creating Layer data
# I0427 18:17:57.360772 2050462464 net.cpp:338] data -> data
# I0427 18:17:57.360792 2050462464 net.cpp:338] data -> label
# I0427 18:17:57.360801 2050462464 net.cpp:113] Setting up data
# I0427 18:17:57.360807 2050462464 hdf5_data_layer.cpp:80] Loading list of HDF5 filenames from: hdf5_classification/data/train.txt
# I0427 18:17:57.360852 2050462464 hdf5_data_layer.cpp:94] Number of HDF5 files: 2
# I0427 18:17:57.363370 2050462464 net.cpp:120] Top shape: 10 4 (40)
# I0427 18:17:57.363392 2050462464 net.cpp:120] Top shape: 10 (10)
# I0427 18:17:57.363440 2050462464 layer_factory.hpp:74] Creating layer fc1
# I0427 18:17:57.363466 2050462464 net.cpp:84] Creating Layer fc1
# I0427 18:17:57.363479 2050462464 net.cpp:380] fc1 <- data
# I0427 18:17:57.363499 2050462464 net.cpp:338] fc1 -> fc1
# I0427 18:17:57.363523 2050462464 net.cpp:113] Setting up fc1
# I0427 18:17:57.368327 2050462464 net.cpp:120] Top shape: 10 40 (400)
# I0427 18:17:57.368348 2050462464 layer_factory.hpp:74] Creating layer relu1
# I0427 18:17:57.368363 2050462464 net.cpp:84] Creating Layer relu1
# I0427 18:17:57.368369 2050462464 net.cpp:380] relu1 <- fc1
# I0427 18:17:57.368376 2050462464 net.cpp:327] relu1 -> fc1 (in-place)
# I0427 18:17:57.368383 2050462464 net.cpp:113] Setting up relu1
# I0427 18:17:57.368388 2050462464 net.cpp:120] Top shape: 10 40 (400)
# I0427 18:17:57.368393 2050462464 layer_factory.hpp:74] Creating layer fc2
# I0427 18:17:57.368401 2050462464 net.cpp:84] Creating Layer fc2
# I0427 18:17:57.368404 2050462464 net.cpp:380] fc2 <- fc1
# I0427 18:17:57.368412 2050462464 net.cpp:338] fc2 -> fc2
# I0427 18:17:57.368420 2050462464 net.cpp:113] Setting up fc2
# I0427 18:17:57.368433 2050462464 net.cpp:120] Top shape: 10 2 (20)
# I0427 18:17:57.368441 2050462464 layer_factory.hpp:74] Creating layer loss
# I0427 18:17:57.368450 2050462464 net.cpp:84] Creating Layer loss
# I0427 18:17:57.368454 2050462464 net.cpp:380] loss <- fc2
# I0427 18:17:57.368813 2050462464 net.cpp:380] loss <- label
# I0427 18:17:57.368854 2050462464 net.cpp:338] loss -> loss
# I0427 18:17:57.368871 2050462464 net.cpp:113] Setting up loss
# I0427 18:17:57.368881 2050462464 layer_factory.hpp:74] Creating layer loss
# I0427 18:17:57.368901 2050462464 net.cpp:120] Top shape: (1)
# I0427 18:17:57.368911 2050462464 net.cpp:122]     with loss weight 1
# I0427 18:17:57.368924 2050462464 net.cpp:167] loss needs backward computation.
# I0427 18:17:57.368932 2050462464 net.cpp:167] fc2 needs backward computation.
# I0427 18:17:57.368938 2050462464 net.cpp:167] relu1 needs backward computation.
# I0427 18:17:57.368944 2050462464 net.cpp:167] fc1 needs backward computation.
# I0427 18:17:57.368950 2050462464 net.cpp:169] data does not need backward computation.
# I0427 18:17:57.368957 2050462464 net.cpp:205] This network produces output loss
# I0427 18:17:57.368965 2050462464 net.cpp:447] Collecting Learning Rate and Weight Decay.
# I0427 18:17:57.368973 2050462464 net.cpp:217] Network initialization done.
# I0427 18:17:57.368979 2050462464 net.cpp:218] Memory required for data: 3484
# I0427 18:17:57.369168 2050462464 solver.cpp:154] Creating test net (#0) specified by net file: hdf5_classification/train_val2.prototxt
# I0427 18:17:57.369199 2050462464 net.cpp:257] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0427 18:17:57.369215 2050462464 net.cpp:42] Initializing net from parameters:
# name: "LogisticRegressionNet"
# state {
#   phase: TEST
# }
# layer {
#   name: "data"
#   type: "HDF5Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_data_param {
#     source: "hdf5_classification/data/test.txt"
#     batch_size: 10
#   }
# }
# layer {
#   name: "fc1"
#   type: "InnerProduct"
#   bottom: "data"
#   top: "fc1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 40
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "fc1"
#   top: "fc1"
# }
# layer {
#   name: "fc2"
#   type: "InnerProduct"
#   bottom: "fc1"
#   top: "fc2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc2"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc2"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0427 18:17:57.369369 2050462464 layer_factory.hpp:74] Creating layer data
# I0427 18:17:57.369380 2050462464 net.cpp:84] Creating Layer data
# I0427 18:17:57.369386 2050462464 net.cpp:338] data -> data
# I0427 18:17:57.369396 2050462464 net.cpp:338] data -> label
# I0427 18:17:57.369403 2050462464 net.cpp:113] Setting up data
# I0427 18:17:57.369408 2050462464 hdf5_data_layer.cpp:80] Loading list of HDF5 filenames from: hdf5_classification/data/test.txt
# I0427 18:17:57.369443 2050462464 hdf5_data_layer.cpp:94] Number of HDF5 files: 1
# I0427 18:17:57.370878 2050462464 net.cpp:120] Top shape: 10 4 (40)
# I0427 18:17:57.370898 2050462464 net.cpp:120] Top shape: 10 (10)
# I0427 18:17:57.370908 2050462464 layer_factory.hpp:74] Creating layer label_data_1_split
# I0427 18:17:57.370918 2050462464 net.cpp:84] Creating Layer label_data_1_split
# I0427 18:17:57.370926 2050462464 net.cpp:380] label_data_1_split <- label
# I0427 18:17:57.370935 2050462464 net.cpp:338] label_data_1_split -> label_data_1_split_0
# I0427 18:17:57.370947 2050462464 net.cpp:338] label_data_1_split -> label_data_1_split_1
# I0427 18:17:57.370956 2050462464 net.cpp:113] Setting up label_data_1_split
# I0427 18:17:57.370965 2050462464 net.cpp:120] Top shape: 10 (10)
# I0427 18:17:57.370972 2050462464 net.cpp:120] Top shape: 10 (10)
# I0427 18:17:57.370980 2050462464 layer_factory.hpp:74] Creating layer fc1
# I0427 18:17:57.370993 2050462464 net.cpp:84] Creating Layer fc1
# I0427 18:17:57.371001 2050462464 net.cpp:380] fc1 <- data
# I0427 18:17:57.371031 2050462464 net.cpp:338] fc1 -> fc1
# I0427 18:17:57.371043 2050462464 net.cpp:113] Setting up fc1
# I0427 18:17:57.371063 2050462464 net.cpp:120] Top shape: 10 40 (400)
# I0427 18:17:57.371076 2050462464 layer_factory.hpp:74] Creating layer relu1
# I0427 18:17:57.371085 2050462464 net.cpp:84] Creating Layer relu1
# I0427 18:17:57.371098 2050462464 net.cpp:380] relu1 <- fc1
# I0427 18:17:57.371110 2050462464 net.cpp:327] relu1 -> fc1 (in-place)
# I0427 18:17:57.371121 2050462464 net.cpp:113] Setting up relu1
# I0427 18:17:57.371129 2050462464 net.cpp:120] Top shape: 10 40 (400)
# I0427 18:17:57.371137 2050462464 layer_factory.hpp:74] Creating layer fc2
# I0427 18:17:57.371148 2050462464 net.cpp:84] Creating Layer fc2
# I0427 18:17:57.371156 2050462464 net.cpp:380] fc2 <- fc1
# I0427 18:17:57.371167 2050462464 net.cpp:338] fc2 -> fc2
# I0427 18:17:57.371178 2050462464 net.cpp:113] Setting up fc2
# I0427 18:17:57.371197 2050462464 net.cpp:120] Top shape: 10 2 (20)
# I0427 18:17:57.371212 2050462464 layer_factory.hpp:74] Creating layer fc2_fc2_0_split
# I0427 18:17:57.371222 2050462464 net.cpp:84] Creating Layer fc2_fc2_0_split
# I0427 18:17:57.371271 2050462464 net.cpp:380] fc2_fc2_0_split <- fc2
# I0427 18:17:57.371300 2050462464 net.cpp:338] fc2_fc2_0_split -> fc2_fc2_0_split_0
# I0427 18:17:57.371315 2050462464 net.cpp:338] fc2_fc2_0_split -> fc2_fc2_0_split_1
# I0427 18:17:57.371326 2050462464 net.cpp:113] Setting up fc2_fc2_0_split
# I0427 18:17:57.371335 2050462464 net.cpp:120] Top shape: 10 2 (20)
# I0427 18:17:57.371343 2050462464 net.cpp:120] Top shape: 10 2 (20)
# I0427 18:17:57.371352 2050462464 layer_factory.hpp:74] Creating layer loss
# I0427 18:17:57.371363 2050462464 net.cpp:84] Creating Layer loss
# I0427 18:17:57.371371 2050462464 net.cpp:380] loss <- fc2_fc2_0_split_0
# I0427 18:17:57.371378 2050462464 net.cpp:380] loss <- label_data_1_split_0
# I0427 18:17:57.371388 2050462464 net.cpp:338] loss -> loss
# I0427 18:17:57.371399 2050462464 net.cpp:113] Setting up loss
# I0427 18:17:57.371409 2050462464 layer_factory.hpp:74] Creating layer loss
# I0427 18:17:57.371430 2050462464 net.cpp:120] Top shape: (1)
# I0427 18:17:57.371439 2050462464 net.cpp:122]     with loss weight 1
# I0427 18:17:57.371449 2050462464 layer_factory.hpp:74] Creating layer accuracy
# I0427 18:17:57.371462 2050462464 net.cpp:84] Creating Layer accuracy
# I0427 18:17:57.371470 2050462464 net.cpp:380] accuracy <- fc2_fc2_0_split_1
# I0427 18:17:57.371479 2050462464 net.cpp:380] accuracy <- label_data_1_split_1
# I0427 18:17:57.371489 2050462464 net.cpp:338] accuracy -> accuracy
# I0427 18:17:57.371500 2050462464 net.cpp:113] Setting up accuracy
# I0427 18:17:57.371532 2050462464 net.cpp:120] Top shape: (1)
# I0427 18:17:57.371543 2050462464 net.cpp:169] accuracy does not need backward computation.
# I0427 18:17:57.371551 2050462464 net.cpp:167] loss needs backward computation.
# I0427 18:17:57.371559 2050462464 net.cpp:167] fc2_fc2_0_split needs backward computation.
# I0427 18:17:57.371567 2050462464 net.cpp:167] fc2 needs backward computation.
# I0427 18:17:57.371575 2050462464 net.cpp:167] relu1 needs backward computation.
# I0427 18:17:57.371583 2050462464 net.cpp:167] fc1 needs backward computation.
# I0427 18:17:57.371592 2050462464 net.cpp:169] label_data_1_split does not need backward computation.
# I0427 18:17:57.371599 2050462464 net.cpp:169] data does not need backward computation.
# I0427 18:17:57.371603 2050462464 net.cpp:205] This network produces output accuracy
# I0427 18:17:57.371608 2050462464 net.cpp:205] This network produces output loss
# I0427 18:17:57.371616 2050462464 net.cpp:447] Collecting Learning Rate and Weight Decay.
# I0427 18:17:57.371623 2050462464 net.cpp:217] Network initialization done.
# I0427 18:17:57.371626 2050462464 net.cpp:218] Memory required for data: 3728
# I0427 18:17:57.371676 2050462464 solver.cpp:42] Solver scaffolding done.
# I0427 18:17:57.371695 2050462464 solver.cpp:222] Solving LogisticRegressionNet
# I0427 18:17:57.371700 2050462464 solver.cpp:223] Learning Rate Policy: step
# I0427 18:17:57.371708 2050462464 solver.cpp:266] Iteration 0, Testing net (#0)
# I0427 18:17:57.374207 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.3132
# I0427 18:17:57.374230 2050462464 solver.cpp:315]     Test net output #1: loss = 0.693363 (* 1 = 0.693363 loss)
# I0427 18:17:57.374264 2050462464 solver.cpp:189] Iteration 0, loss = 0.693435
# I0427 18:17:57.374274 2050462464 solver.cpp:204]     Train net output #0: loss = 0.693435 (* 1 = 0.693435 loss)
# I0427 18:17:57.374284 2050462464 solver.cpp:464] Iteration 0, lr = 0.01
# I0427 18:17:57.383949 2050462464 solver.cpp:266] Iteration 1000, Testing net (#0)
# I0427 18:17:57.386273 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.7788
# I0427 18:17:57.386301 2050462464 solver.cpp:315]     Test net output #1: loss = 0.469507 (* 1 = 0.469507 loss)
# I0427 18:17:57.386320 2050462464 solver.cpp:189] Iteration 1000, loss = 0.681959
# I0427 18:17:57.386328 2050462464 solver.cpp:204]     Train net output #0: loss = 0.681959 (* 1 = 0.681959 loss)
# I0427 18:17:57.386335 2050462464 solver.cpp:464] Iteration 1000, lr = 0.01
# I0427 18:17:57.395622 2050462464 solver.cpp:266] Iteration 2000, Testing net (#0)
# I0427 18:17:57.397874 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.8272
# I0427 18:17:57.397893 2050462464 solver.cpp:315]     Test net output #1: loss = 0.424085 (* 1 = 0.424085 loss)
# I0427 18:17:57.397912 2050462464 solver.cpp:189] Iteration 2000, loss = 0.180941
# I0427 18:17:57.397918 2050462464 solver.cpp:204]     Train net output #0: loss = 0.180941 (* 1 = 0.180941 loss)
# I0427 18:17:57.397925 2050462464 solver.cpp:464] Iteration 2000, lr = 0.01
# I0427 18:17:57.407959 2050462464 solver.cpp:266] Iteration 3000, Testing net (#0)
# I0427 18:17:57.410395 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.8204
# I0427 18:17:57.410429 2050462464 solver.cpp:315]     Test net output #1: loss = 0.421125 (* 1 = 0.421125 loss)
# I0427 18:17:57.410995 2050462464 solver.cpp:189] Iteration 3000, loss = 0.46534
# I0427 18:17:57.411016 2050462464 solver.cpp:204]     Train net output #0: loss = 0.46534 (* 1 = 0.46534 loss)
# I0427 18:17:57.411023 2050462464 solver.cpp:464] Iteration 3000, lr = 0.01
# I0427 18:17:57.420027 2050462464 solver.cpp:266] Iteration 4000, Testing net (#0)
# I0427 18:17:57.422413 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.778
# I0427 18:17:57.422449 2050462464 solver.cpp:315]     Test net output #1: loss = 0.444832 (* 1 = 0.444832 loss)
# I0427 18:17:57.422472 2050462464 solver.cpp:189] Iteration 4000, loss = 0.48123
# I0427 18:17:57.422482 2050462464 solver.cpp:204]     Train net output #0: loss = 0.48123 (* 1 = 0.48123 loss)
# I0427 18:17:57.422488 2050462464 solver.cpp:464] Iteration 4000, lr = 0.01
# I0427 18:17:57.432149 2050462464 solver.cpp:266] Iteration 5000, Testing net (#0)
# I0427 18:17:57.434478 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.8268
# I0427 18:17:57.434512 2050462464 solver.cpp:315]     Test net output #1: loss = 0.420855 (* 1 = 0.420855 loss)
# I0427 18:17:57.434535 2050462464 solver.cpp:189] Iteration 5000, loss = 0.118331
# I0427 18:17:57.434545 2050462464 solver.cpp:204]     Train net output #0: loss = 0.118331 (* 1 = 0.118331 loss)
# I0427 18:17:57.434551 2050462464 solver.cpp:464] Iteration 5000, lr = 0.001
# I0427 18:17:57.444418 2050462464 solver.cpp:266] Iteration 6000, Testing net (#0)
# I0427 18:17:57.446602 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.8412
# I0427 18:17:57.446616 2050462464 solver.cpp:315]     Test net output #1: loss = 0.38087 (* 1 = 0.38087 loss)
# I0427 18:17:57.447098 2050462464 solver.cpp:189] Iteration 6000, loss = 0.495099
# I0427 18:17:57.447116 2050462464 solver.cpp:204]     Train net output #0: loss = 0.495099 (* 1 = 0.495099 loss)
# I0427 18:17:57.447129 2050462464 solver.cpp:464] Iteration 6000, lr = 0.001
# I0427 18:17:57.457746 2050462464 solver.cpp:266] Iteration 7000, Testing net (#0)
# I0427 18:17:57.459985 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.8396
# I0427 18:17:57.460000 2050462464 solver.cpp:315]     Test net output #1: loss = 0.379928 (* 1 = 0.379928 loss)
# I0427 18:17:57.460016 2050462464 solver.cpp:189] Iteration 7000, loss = 0.395276
# I0427 18:17:57.460049 2050462464 solver.cpp:204]     Train net output #0: loss = 0.395276 (* 1 = 0.395276 loss)
# I0427 18:17:57.460057 2050462464 solver.cpp:464] Iteration 7000, lr = 0.001
# I0427 18:17:57.469389 2050462464 solver.cpp:266] Iteration 8000, Testing net (#0)
# I0427 18:17:57.471932 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.836
# I0427 18:17:57.471952 2050462464 solver.cpp:315]     Test net output #1: loss = 0.380544 (* 1 = 0.380544 loss)
# I0427 18:17:57.471973 2050462464 solver.cpp:189] Iteration 8000, loss = 0.159647
# I0427 18:17:57.471982 2050462464 solver.cpp:204]     Train net output #0: loss = 0.159648 (* 1 = 0.159648 loss)
# I0427 18:17:57.471987 2050462464 solver.cpp:464] Iteration 8000, lr = 0.001
# I0427 18:17:57.481161 2050462464 solver.cpp:266] Iteration 9000, Testing net (#0)
# I0427 18:17:57.483414 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.8404
# I0427 18:17:57.483429 2050462464 solver.cpp:315]     Test net output #1: loss = 0.378355 (* 1 = 0.378355 loss)
# I0427 18:17:57.483822 2050462464 solver.cpp:189] Iteration 9000, loss = 0.489251
# I0427 18:17:57.483839 2050462464 solver.cpp:204]     Train net output #0: loss = 0.489252 (* 1 = 0.489252 loss)
# I0427 18:17:57.483847 2050462464 solver.cpp:464] Iteration 9000, lr = 0.001
# I0427 18:17:57.492985 2050462464 solver.cpp:334] Snapshotting to hdf5_classification/data/train_iter_10000.caffemodel
# I0427 18:17:57.493166 2050462464 solver.cpp:342] Snapshotting solver state to hdf5_classification/data/train_iter_10000.solverstate
# I0427 18:17:57.493278 2050462464 solver.cpp:248] Iteration 10000, loss = 0.39081
# I0427 18:17:57.493309 2050462464 solver.cpp:266] Iteration 10000, Testing net (#0)
# I0427 18:17:57.495578 2050462464 solver.cpp:315]     Test net output #0: accuracy = 0.838
# I0427 18:17:57.495596 2050462464 solver.cpp:315]     Test net output #1: loss = 0.378208 (* 1 = 0.378208 loss)
# I0427 18:17:57.495602 2050462464 solver.cpp:253] Optimization Done.
# I0427 18:17:57.495607 2050462464 caffe.cpp:134] Optimization Done.

# %%
# Clean up (comment this out if you want to examine the hdf5_classification/data directory).
shutil.rmtree(dirname)
